# %% [markdown]
# # MODULES

# %%
"""
MODULES:
        --- A MODULE IS A FILE CONTAINING THE DEFINATION AND STATEMENT 
        --- A FILE NAME IS THE MODULE NAME WITH THE SUFFIX .PY
        --- MODULES CAN CONTAIN FUCNTIONS , CLASSES AND VARIABLES AND CAN BE IMPORTED INTO THE  OTHER MODULES OR SCRIPT TO BE USED 
        --- EASY TO DEBUG

        TYPES OF MODULES 
        BUILD IN MODULES --- > 
        THIRD PARTY MODULES
        USER DEFINE MODULES


"""
# Out:
# '\nMODULES:\n        --- A MODULE IS A FILE CONTAINING THE DEFINATION AND STATEMENT \n        --- A FILE NAME IS THE MODULE NAME WITH THE SUFFIX .PY\n        --- MODULES CAN CONTAIN FUCNTIONS , CLASSES AND VARIABLES AND CAN BE IMPORTED INTO THE  OTHER MODULES OR SCRIPT TO BE USED \n        --- EASY TO DEBUG\n\n        TYPES OF MODULES \n        BUILD IN MODULES\n        USER DEFINE MODULES\n        \n\n'

# %% [markdown]
# # BUILD IN MODULES

# %%
import math 
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
math.factorial(5)
# Out:
# 120

# %%
import ritz

# %% [markdown]
# # THIRD PARTY MODULES

# %%
ritz.add(1,2)
# Out:
# Addition Of Two Number is  3

# %%
ritz.is_even(2)
# Out:
# True

# %% [markdown]
# # Packages
