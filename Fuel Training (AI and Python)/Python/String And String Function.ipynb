# %%
units =eval(input("Enter The Number:"))
if units<=100:
    print("No Charge")
elif units <=200:
    total_amount = (units-100)*5
    print(total_amount)
else:
    total_Amount = 500 + ((units-200)*10)
    print(total_Amount)

# %%
list1 = [11,22,33]

# %%
list1 = [10,20,30,40,50]
list2 = [0,1,2,3,4]

a = list(map(pow,list1,list2))
a
# Out:
# [1, 20, 900, 64000, 6250000]

# %%
list1 = [1,2,3,4,5,6]
list2 = [3,4,5,6,7,8]

def mul_list(s):
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-1ef3241fb767> in <cell line: 4>()
#       2 list2 = [3,4,5,6,7,8]
#       3
# ----> 4 a = list(map(list1,list2))
#
# TypeError: 'list' object is not callable
